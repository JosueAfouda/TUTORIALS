# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueAfouda/TUTORIALS/blob/main/tuto_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Auteur : [Josué AFOUDA](https://www.youtube.com/channel/UCpd56FfjlkKbkHlbgY6XE3w)

# %% [markdown]
# ![matplotlib.png](data:image/png;base64,...)

# %%
# Importation de l'interface pyplot de Matplotlib

import matplotlib.pyplot as plt

# %% [markdown]
# # Tracés linéaires

# %%
# Tracé d'une courbe (line plot)
annee = [1950, 1970, 1990, 2010]
population = [2600000, 3700000, 5300000, 7000000]

plt.plot(annee, population)
plt.xlabel("Année")
plt.ylabel("Population (millions)")
plt.title("Evolution de la population")
plt.show()

# %%
# On peut personnaliser le style de ligne, le marqueur et la couleur
plt.plot(annee, population, linestyle='--', marker='v', color='r')
plt.xlabel("Année")
plt.ylabel("Population (millions)")
plt.title("Evolution de la population")
plt.show()

# %%
import pandas as pd

# %%
 apple = pd.read_csv("AAPL.csv")
 apple.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-08-30  210.160004  210.449997  207.199997  208.740005  206.689255
# 1  2019-09-03  206.429993  206.979996  204.220001  205.699997  203.679108
# 2  2019-09-04  208.389999  209.479996  207.320007  209.190002  207.134857
# 3  2019-09-05  212.000000  213.970001  211.509995  213.279999  211.184647
# 4  2019-09-06  214.050003  214.419998  212.509995  213.259995  211.164841
#
#      Volume
# 0  21143400
# 1  20023000
# 2  19188100
# 3  23913700
# 4  19362300

# %%
apple.Date.dtype
# Out:
# dtype('O')

# %%
apple.Date = pd.to_datetime(apple.Date)
apple.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
# Prix de clôture
plt.figure(figsize=(12, 6))
plt.plot(apple.Date, apple.Close)
plt.ylabel("Prix de cloture")
plt.title("Evolution du prix de cloture de APPLE")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(apple.Date, apple.Low, label="Bas")
plt.plot(apple.Date, apple.High, label="Haut")
plt.ylabel("Prix")
plt.legend()
plt.show()

# %% [markdown]
# # Nuages de Points

# %%
# Nuage de points (scatter plot)
plt.figure(figsize=(10,8))
plt.scatter(apple.Volume, apple.Close)
plt.xlabel('Volume négocié')
plt.ylabel("Prix de cloture")
plt.show()

# %%
# Importez le fichier 'gapminder.txt'

gap = pd.read_csv("gapminder.txt")

# Affichez les cinq premières lignes de gap

gap.head()
# Out:
#    Unnamed: 0      country  year  population      cont  life_exp       gdp_cap
# 0          11  Afghanistan  2007  31889923.0      Asia    43.828    974.580338
# 1          23      Albania  2007   3600523.0    Europe    76.423   5937.029526
# 2          35      Algeria  2007  33333216.0    Africa    72.301   6223.367465
# 3          47       Angola  2007  12420476.0    Africa    42.731   4797.231267
# 4          59    Argentina  2007  40301927.0  Americas    75.320  12779.379640

# %%
# Tracez un nuage de points montrant l'espérance de vie (life_exp) en fonction du PIB (gdp_cap)

plt.figure(figsize = (12, 7))

plt.scatter(gap['gdp_cap'], gap['life_exp'])

plt.xlabel("PIB")

plt.ylabel("Espérance de vie)")

plt.title("Espérance de vie VS PIB")

plt.show()

# %%
# Reprenez le code du graphique précédent en ajoutant plt.xscale('log') et plt.grid(True)

plt.figure(figsize = (12, 7))

plt.scatter(gap['gdp_cap'], gap['life_exp'])

plt.xscale('log')

plt.xlabel("Log du PIB")

plt.ylabel("Espérance de vie)")

plt.title("Espérance de vie VS PIB")

plt.grid(True)

plt.show()

# %%
gap.cont.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
# Tracez un nuage de points montrant l'espérance de vie en fonction du PIB dans le continent africain

afr = gap[gap.cont == "Africa"]

plt.figure(figsize = (12, 7))

plt.scatter(afr['gdp_cap'], afr['life_exp'])

plt.xlabel("PIB")

plt.ylabel("Espérance de vie)")

plt.title("Espérance de vie VS PIB")

plt.show()

# %% [markdown]
# # Boîte à moustache

# %%
# Orientation verticale
plt.boxplot(gap.life_exp)
plt.show()

# %%
# Orientation horizontale
plt.boxplot(gap.life_exp, vert=False)
plt.show()

# %%
import seaborn as sns

# %%
# PIB par continent
plt.figure(figsize=(10,6))
sns.boxplot(x = "cont", y = "gdp_cap", data = gap)
plt.xlabel("Continent")
plt.ylabel("PIB")
plt.title("PIP par continent")
plt.show()

# %% [markdown]
# Si vous travaillez en Statistique et que vous aimerez créer rapidement de jolis graphiques avec peu de lignes de codes, alors vous devez absolument considérer l'utilisation de Seaborn. Pour en apprendre davantage sur Seaborn, je vous conseille de vous procurer mon livre [Statistique et Simulation avec Python : Cours et Exercices corrigés](https://buy.stripe.com/eVaaIGgfQefgbcIfZ3) disponible en version [papier](https://www.amazon.fr/gp/product/B08SCYRX3H/ref=dbs_a_def_rwt_hsch_vapi_tu00_p1_i1) en version [pdf](https://buy.stripe.com/eVaaIGgfQefgbcIfZ3).

# %% [markdown]
# ![cover_3d_livre_stats_python.png](data:image/png;base64,...)

# %% [markdown]
# # Diagramme à barres

# %%
# Exemple de diagramme à barre

x1 = [1, 3, 4, 5, 6, 7, 9]

y1 = [4, 7, 2, 4, 7, 8, 3]

plt.bar(x1, y1, label="Blue Bar", color='b')

plt.xlabel("nombre")

plt.ylabel("Taille")

plt.title("Exemple de diagramme à barre")

plt.legend()

plt.show()

# %%
# Créez une dataframe du PIB moyen par continent

pib_moy = gap.groupby("cont")['gdp_cap'].mean()
pib_moy = pd.DataFrame(pib_moy)
pib_moy
# Out:
#                gdp_cap
# cont
# Africa     3089.032605
# Americas  11003.031625
# Asia      12473.026870
# Europe    25054.481636
# Oceania   29810.188275

# %%
# Construire un diagramme à barres montrant le PIB moyen par continent

plt.bar(pib_moy.index, pib_moy['gdp_cap'], label = "PIB per continent", color = 'g')

plt.xlabel("Continent")

plt.ylabel("PIB moyen")

plt.title("PIB moyen par continent")

plt.legend()

plt.show()

# %% [markdown]
# # Diagramme circulaire

# %%
# Exemple de diagramme circulaire
labels = "S1", "S2", "S3"
sections = [56, 66, 24]
plt.pie(sections, labels = labels, colors = ['c', 'g', 'y'])
plt.title("Exemple de graphique circulaire")
plt.show()

# %%
# On peut customiser le graphique précédent

plt.pie(sections, labels = labels, colors = ['c', 'g', 'y'],
        explode = (0, 0.1, 0.1), # Essayez aussi explode = (0, 0.1, 0)
        autopct = '%1.2f%%')

plt.title('Exemple de diagramme circulaire') 

plt.show()

# %%
# Construisez un diagramme circulaire montrant le PIB moyen par continent

plt.pie(pib_moy.gdp_cap, labels = pib_moy.index)
plt.title("PIB moyen par continent")
plt.show()

# %% [markdown]
# # Histogramme

# %%
# Construction d'un histogramme

plt.hist(apple.Close)
plt.title("Histogramme du prix de cloture de APPLE")
plt.show()

# %%
# Changement du nombre de bacs (bins)

plt.hist(apple.Close, bins = 20)
plt.title("Histogramme du prix de cloture de APPLE")
plt.show()

# %%
# Avec une boucle for, construire les histogrammes des variables population, life_exp et gdp_cap

for i in ["population", "life_exp", "gdp_cap"]:
  plt.hist(gap[i])
  plt.title(i)
  plt.show()

# %% [markdown]
# # Subplots et Sauvegarde d'un graphique

# %%
plt.subplot(2, 1, 1)
plt.hist(apple.Close)
plt.ylabel("Prix de cloture")
plt.title("Histogramme")

plt.subplot(2, 1, 2)
plt.boxplot(apple.Close, vert=False)
plt.yticks([1], ["Prix de cloture"])
plt.title("Boite à moustache")

plt.tight_layout()
plt.savefig("AppleClosedPrice.png", dpi=900)

# %%
noms_variables = [
    "age", "workclass", "fnlwgt", "education", "education-num",
    "marital-status", "occupation", "relationship", "race",
    "sex", "capital-gain", "capital-loss", "hours-per-week",
    "native-country", "class"
]

df = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",
    header=None,
    names = noms_variables
)

df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class             object
# dtype: object

# %%
# Colonne numériques
cols_num = df.select_dtypes(exclude="object").columns.to_list()
cols_num
# Out:
# ['age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
plt.figure(figsize=(18,7)) 
for i,col in enumerate(cols_num):
    plt.subplot(2, len(cols_num), i+1)
    plt.hist(df[col])
    plt.title(col)
for i,col in enumerate(cols_num):
    plt.subplot(2, len(cols_num), i+len(cols_num)+1)
    plt.boxplot(df[col], vert=False)
    plt.yticks([])
plt.tight_layout()
plt.savefig('Visualisation.png', dpi=900)

# %% [markdown]
# # Conclusion
